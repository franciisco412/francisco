# %%
print("Que tipo de conversion deseas: (Escriba el numero)")
print("1.-Longitud")
print("2.-Temperatura")
print("3.-Masa")
print("4.-Volumen")
print("5.-Tiempo")
conv=int(input())

if(conv==1):
    print("Que unidades deseas convertir: (Escriba el numero)")
    print("1.-cm/pulgadas")
    print("2.-m/pies")
    print("3.-m/pulgadas")
    print("4.-m/millas")
    print("5.-Km/yardas")
    print("6.-Km/millas")
    uni=int(input())
    if(uni==1):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad/2.54
        print(cantidad,"cm a pulgadas: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==2):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*3.281
        print(cantidad,"m a pies: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==3):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*39.37
        print(cantidad,"m a pulgadas: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==4):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad/1609
        print(cantidad,"m a millas: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==5):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*1094
        print(cantidad,"Km a Yardas: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==6):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad/1.609
        print(cantidad,"Km a millas: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
elif(conv==2):
    print("Que unidades deseas convertir: (Escriba el numero)")
    print("1.-celsius/farenheit")
    print("2.-celsius/kelvin")
    print("3.-kelvin/farenheit")
    uni=int(input())
    if(uni==1):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=(cantidad(9/5))+32
        print(cantidad,"°C a Farenheit: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==2):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad+273.15
        print(cantidad,"°C a Kelvin: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==3):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=((cantidad-273.15)*(9/5))+32
        print(cantidad,"°K a Farenheit: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
elif(conv==3):
    print("Que unidades deseas convertir: (Escriba el numero)")
    print("1.-Kg/Libras")
    print("2.-Gramos/Onzas")
    print("3.-Kg/Toneladas")
    uni=int(input())
    if(uni==1):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*2.205
        print(cantidad,"Kg a Libras: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==2):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad/28.35
        print(cantidad,"g a Onzas: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==3):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad/1000
        print(cantidad,"Kg a Toneladas: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
elif(conv==4):
    print("Que unidades deseas convertir: (Escriba el numero)")
    print("1.-litro/galon")
    print("2.-m^3/yd^3")
    print("3.-m^3/pulgada^3")
    print("4.-m^3/pies^3")
    uni=int(input())
    if(uni==1):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*3.785
        print(cantidad,"lt a Galon: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==2):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*1.308
        print(cantidad,"m^3 a Yd^3: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==3):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*1.308
        print(cantidad,"m^3 a pulgada^3: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==4):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*35.315
        print(cantidad,"m^3 a pies^3: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
elif(conv==5):
    print("Que unidades deseas convertir: (Escriba el numero)")
    print("1.-Horas/Minutos")
    print("2.-Minutos/Segundos")
    print("3.-Segundos/Milisegundos")
    uni=int(input())
    if(uni==1):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*60
        print(cantidad,"Hrs a Min: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==2):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*60
        print(cantidad,"Min a Seg: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close() 
    elif(uni==3):
        print("Ingresa la cantidad que deseas convertir: ")
        cantidad=float(input())
        x=cantidad*1000
        print(cantidad,"Seg a Miliseg: ",x)
        f=open('archivo.txt','a') 
        f.write("\n ")
        f.write("El resultado de la conversion es: ")
        f.write(str(x)) 
        f.close()
# Out:
# Que tipo de conversion deseas: (Escriba el numero)
# 1.-Longitud
# 2.-Temperatura
# 3.-Masa
# 4.-Volumen
# 5.-Tiempo
# 5
# Que unidades deseas convertir: (Escriba el numero)
# 1.-Horas/Minutos
# 2.-Minutos/Segundos
# 3.-Segundos/Milisegundos
# 1
# Ingresa la cantidad que deseas convertir:
# 4256
# 4256.0 Hrs a Min:  255360.0

# %%
f=open('archivo.txt','a') #
f.write("") #
f.write("15") #
f.close() #
